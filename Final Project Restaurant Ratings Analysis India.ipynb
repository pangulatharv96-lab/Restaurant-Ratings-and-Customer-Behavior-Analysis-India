# %% [markdown]
# <h1>Final Project Restaurant Ratings Analysis India

# %% [markdown]
# <h2>Importing Necssary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns
import warnings 
from warnings import filterwarnings 
filterwarnings("ignore")

# %% [markdown]
# <h2>Loading Dataset

# %%
excel = pd.ExcelFile(r"C:\Data science\All Projects and Assignment\Excle projects\Final Project Restaurant Ratings Analysis India.xlsx")
print(excel.sheet_names)
# Out:
# ['Consumers', 'Consumers preference', 'Restaurant', 'Rating', 'Restaurant Cuisines']

# %%
df = pd.read_excel(r"C:\Data science\All Projects and Assignment\Excle projects\Final Project Restaurant Ratings Analysis India.xlsx",
                   sheet_name="Consumers")

# %%
df = pd.read_excel(r"C:\Data science\All Projects and Assignment\Excle projects\Final Project Restaurant Ratings Analysis India.xlsx",
                   sheet_name="Consumers preference")

# %%
df = pd.read_excel(r"C:\Data science\All Projects and Assignment\Excle projects\Final Project Restaurant Ratings Analysis India.xlsx",
                   sheet_name="Restaurant")

# %%
df = pd.read_excel(r"C:\Data science\All Projects and Assignment\Excle projects\Final Project Restaurant Ratings Analysis India.xlsx",
                   sheet_name="Rating")

# %%
df = pd.read_excel(r"C:\Data science\All Projects and Assignment\Excle projects\Final Project Restaurant Ratings Analysis India.xlsx",
                   sheet_name="Restaurant Cuisines")

# %%
sheets = pd.read_excel(r"C:\Data science\All Projects and Assignment\Excle projects\Final Project Restaurant Ratings Analysis India.xlsx", sheet_name=None)

# Dictionary of DataFrames
df1 = sheets[list(sheets.keys())[0]]
df2 = sheets[list(sheets.keys())[1]]
df3 = sheets[list(sheets.keys())[2]]
df4 = sheets[list(sheets.keys())[3]]
df5 = sheets[list(sheets.keys())[4]]

# %%
df1
# Out:
#      Consumer_ID       City           State  Age  Gender Occupation  \
# 0         C00001     Mumbai     Maharashtra   27  Female   Employed
# 1         C00002      Delhi           Delhi   34    Male   Business
# 2         C00003  Bengaluru       Karnataka   24  Female    Student
# 3         C00004    Chennai      Tamil Nadu   30    Male   Employed
# 4         C00005  Hyderabad       Telangana   37  Female   Business
# ...          ...        ...             ...  ...     ...        ...
# 4995      C04996       Pune     Maharashtra   32    Male   Employed
# 4996      C04997    Kolkata     West Bengal   34  Female   Business
# 4997      C04998  Ahmedabad         Gujarat   24    Male    Student
# 4998      C04999     Jaipur       Rajasthan   35  Female   Employed
# 4999      C05000     Indore  Madhya Pradesh   37    Male   Business
#
#      Marital_Status Smoker Drink_Level Budget_Level    Transport_Mode
# 0            Single     No      Casual       Medium              Bike
# ...

# %%
df2
# Out:
#      Consumer_ID Preferred_Cuisine
# 0         C00001            Indian
# 1         C00002           Chinese
# 2         C00003      South Indian
# 3         C00004      North Indian
# 4         C00005       Street Food
# ...          ...               ...
# 4995      C04996      North Indian
# 4996      C04997       Street Food
# 4997      C04998         Fast Food
# 4998      C04999       Continental
# 4999      C05000           Italian
#
# [5000 rows x 2 columns]

# %%
df3
# Out:
#      Restaurant_ID   Restaurant_Name        City          State Country  \
# 0           R00001     Delight Dhaba        Pune    Maharashtra   India
# 1           R00002      Delight Cafe  Chandigarh     Chandigarh   India
# 2           R00003     Plaza Kitchen       Delhi          Delhi   India
# 3           R00004  House Restaurant       Patna          Bihar   India
# 4           R00005   Heritage Palace   Bengaluru      Karnataka   India
# ...            ...               ...         ...            ...     ...
# 4995        R04996     Garden Bistro       Delhi          Delhi   India
# 4996        R04997      Urban Palace    Amritsar         Punjab   India
# 4997        R04998      Royal Palace      Mumbai    Maharashtra   India
# 4998        R04999    Classic Corner       Patna          Bihar   India
# 4999        R05000       Green Dhaba       Noida  Uttar Pradesh   India
#
#      Price_Range Pure_Veg Alcohol_Served  Parking Franchise Online_Delivery
# ...

# %%
df4
# Out:
#      Consumer_ID Restaurant_ID  Overall_Rating  Food_Rating  Service_Rating  \
# 0         C00001        R03681               4            4               3
# 1         C00002        R00349               4            4               5
# 2         C00003        R02274               3            2               3
# 3         C00004        R00297               3            3               2
# 4         C00005        R04163               3            5               3
# ...          ...           ...             ...          ...             ...
# 4995      C04996        R00791               3            2               5
# 4996      C04997        R04703               2            2               2
# 4997      C04998        R03950               4            4               5
# 4998      C04999        R03003               4            5               2
# 4999      C05000        R03957               4            4               2
#
#       Value_for_Money
# 0                   4
# ...

# %%
df5
# Out:
#      Restaurant_ID Cuisine_Type
# 0           R00001       Bakery
# 1           R00002      Seafood
# 2           R00003     Gujarati
# 3           R00004      Bengali
# 4           R00005    Fast Food
# ...            ...          ...
# 4995        R04996       Kerala
# 4996        R04997    Chettinad
# 4997        R04998   Rajasthani
# 4998        R04999         Cafe
# 4999        R05000     Kashmiri
#
# [5000 rows x 2 columns]

# %% [markdown]
# <h2>Understanding Dateset from all tables

# %% [raw]
# This dataset constitutes the restaurant recommendation and rating system in India, integrating consumer demographics, preferences, restaurant details, cuisines, and ratings.
# This is a relational dataset, with similarities to a real-world food delivery or restaurant review platform.

# %% [markdown]
# - The dataset contains 5 Tables
#    - consumers
#    - consumer preference
#    - Restaurant
#    - Ratings
#    - Restaurant cuisines

# %% [markdown]
# <h3>Table 1 : Consumers

# %%
df1.shape
# Out:
# (5000, 11)

# %%
df1.columns
# Out:
# Index(['Consumer_ID', 'City', 'State', 'Age', 'Gender', 'Occupation',
#        'Marital_Status', 'Smoker', 'Drink_Level', 'Budget_Level',
#        'Transport_Mode'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Consumer_ID     5000 non-null   object
#  1   City            5000 non-null   object
#  2   State           5000 non-null   object
#  3   Age             5000 non-null   int64
#  4   Gender          5000 non-null   object
#  5   Occupation      5000 non-null   object
#  6   Marital_Status  5000 non-null   object
#  7   Smoker          5000 non-null   object
#  8   Drink_Level     5000 non-null   object
#  9   Budget_Level    5000 non-null   object
#  10  Transport_Mode  5000 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 429.8+ KB

# %%
df1.dtypes
# Out:
# Consumer_ID       object
# City              object
# State             object
# Age                int64
# Gender            object
# Occupation        object
# Marital_Status    object
# Smoker            object
# Drink_Level       object
# Budget_Level      object
# Transport_Mode    object
# dtype: object

# %%
df1.head()
# Out:
#   Consumer_ID       City        State  Age  Gender Occupation Marital_Status  \
# 0      C00001     Mumbai  Maharashtra   27  Female   Employed         Single
# 1      C00002      Delhi        Delhi   34    Male   Business        Married
# 2      C00003  Bengaluru    Karnataka   24  Female    Student         Single
# 3      C00004    Chennai   Tamil Nadu   30    Male   Employed        Married
# 4      C00005  Hyderabad    Telangana   37  Female   Business        Married
#
#   Smoker Drink_Level Budget_Level    Transport_Mode
# 0     No      Casual       Medium              Bike
# 1    Yes      Social         High               Car
# 2     No         Non          Low  Public Transport
# 3     No      Casual       Medium              Bike
# 4    Yes      Social         High               Car

# %%
df1.sample()
# Out:
#     Consumer_ID    City        State  Age  Gender Occupation Marital_Status  \
# 990      C00991  Mumbai  Maharashtra   27  Female   Employed         Single
#
#     Smoker Drink_Level Budget_Level Transport_Mode
# 990     No      Casual       Medium           Bike

# %%
df1.tail()
# Out:
#      Consumer_ID       City           State  Age  Gender Occupation  \
# 4995      C04996       Pune     Maharashtra   32    Male   Employed
# 4996      C04997    Kolkata     West Bengal   34  Female   Business
# 4997      C04998  Ahmedabad         Gujarat   24    Male    Student
# 4998      C04999     Jaipur       Rajasthan   35  Female   Employed
# 4999      C05000     Indore  Madhya Pradesh   37    Male   Business
#
#      Marital_Status Smoker Drink_Level Budget_Level    Transport_Mode
# 4995        Married     No      Casual       Medium              Bike
# 4996        Married    Yes      Social         High               Car
# 4997         Single     No         Non          Low  Public Transport
# 4998        Married     No      Casual       Medium              Bike
# 4999        Married    Yes      Social         High               Car

# %% [markdown]
# <h2>checking numeric and categorical columns

# %%
numeric_columns=df1.select_dtypes(["int64","float64"])
numeric_columns
# Out:
#       Age
# 0      27
# 1      34
# 2      24
# 3      30
# 4      37
# ...   ...
# 4995   32
# 4996   34
# 4997   24
# 4998   35
# 4999   37
#
# [5000 rows x 1 columns]

# %%
numeric_columns.columns
# Out:
# Index(['Age'], dtype='object')

# %%
categorical_columns=df1.select_dtypes(["object"])
categorical_columns
# Out:
#      Consumer_ID       City           State  Gender Occupation Marital_Status  \
# 0         C00001     Mumbai     Maharashtra  Female   Employed         Single
# 1         C00002      Delhi           Delhi    Male   Business        Married
# 2         C00003  Bengaluru       Karnataka  Female    Student         Single
# 3         C00004    Chennai      Tamil Nadu    Male   Employed        Married
# 4         C00005  Hyderabad       Telangana  Female   Business        Married
# ...          ...        ...             ...     ...        ...            ...
# 4995      C04996       Pune     Maharashtra    Male   Employed        Married
# 4996      C04997    Kolkata     West Bengal  Female   Business        Married
# 4997      C04998  Ahmedabad         Gujarat    Male    Student         Single
# 4998      C04999     Jaipur       Rajasthan  Female   Employed        Married
# 4999      C05000     Indore  Madhya Pradesh    Male   Business        Married
#
# ...

# %%
categorical_columns.columns
# Out:
# Index(['Consumer_ID', 'City', 'State', 'Gender', 'Occupation',
#        'Marital_Status', 'Smoker', 'Drink_Level', 'Budget_Level',
#        'Transport_Mode'],
#       dtype='object')

# %% [markdown]
# <h2>Checking unique values in dataset

# %%
df1.nunique()
# Out:
# Consumer_ID       5000
# City                10
# State                9
# Age                 19
# Gender               2
# Occupation           3
# Marital_Status       2
# Smoker               2
# Drink_Level          3
# Budget_Level         3
# Transport_Mode       3
# dtype: int64

# %%
numeric_columns.nunique()
# Out:
# Age    19
# dtype: int64

# %%
categorical_columns.nunique()
# Out:
# Consumer_ID       5000
# City                10
# State                9
# Gender               2
# Occupation           3
# Marital_Status       2
# Smoker               2
# Drink_Level          3
# Budget_Level         3
# Transport_Mode       3
# dtype: int64

# %%
df1["City"].unique()
# Out:
# array(['Mumbai', 'Delhi', 'Bengaluru', 'Chennai', 'Hyderabad', 'Pune',
#        'Kolkata', 'Ahmedabad', 'Jaipur', 'Indore'], dtype=object)

# %%
df1["State"].unique()
# Out:
# array(['Maharashtra', 'Delhi', 'Karnataka', 'Tamil Nadu', 'Telangana',
#        'West Bengal', 'Gujarat', 'Rajasthan', 'Madhya Pradesh'],
#       dtype=object)

# %%
df1["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df1["Occupation"].unique()
# Out:
# array(['Employed', 'Business', 'Student'], dtype=object)

# %%
df1["Marital_Status"].unique()
# Out:
# array(['Single', 'Married'], dtype=object)

# %%
df1["Smoker"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df1["Drink_Level"].unique()
# Out:
# array(['Casual', 'Social', 'Non'], dtype=object)

# %%
df1["Budget_Level"].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
df1["Transport_Mode"].unique()
# Out:
# array(['Bike', 'Car', 'Public Transport'], dtype=object)

# %% [markdown]
# <h2>Checking About Null Values

# %%
df1.isnull().sum()
# Out:
# Consumer_ID       0
# City              0
# State             0
# Age               0
# Gender            0
# Occupation        0
# Marital_Status    0
# Smoker            0
# Drink_Level       0
# Budget_Level      0
# Transport_Mode    0
# dtype: int64

# %% [markdown]
# <h4>There is no null values are present in table

# %% [markdown]
# <h3>Table 2 : Consumers preference

# %%
df2.shape
# Out:
# (5000, 2)

# %%
df2.columns
# Out:
# Index(['Consumer_ID', 'Preferred_Cuisine'], dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Consumer_ID        5000 non-null   object
#  1   Preferred_Cuisine  5000 non-null   object
# dtypes: object(2)
# memory usage: 78.3+ KB

# %%
df2.dtypes
# Out:
# Consumer_ID          object
# Preferred_Cuisine    object
# dtype: object

# %%
data.head()
# Out:
#   Consumer_ID       City        State  Age  Gender Occupation Marital_Status  \
# 0      C00001     Mumbai  Maharashtra   27  Female   Employed         Single
# 1      C00002      Delhi        Delhi   34    Male   Business        Married
# 2      C00003  Bengaluru    Karnataka   24  Female    Student         Single
# 3      C00004    Chennai   Tamil Nadu   30    Male   Employed        Married
# 4      C00005  Hyderabad    Telangana   37  Female   Business        Married
#
#   Smoker Drink_Level Budget_Level    Transport_Mode
# 0     No      Casual       Medium              Bike
# 1    Yes      Social         High               Car
# 2     No         Non          Low  Public Transport
# 3     No      Casual       Medium              Bike
# 4    Yes      Social         High               Car

# %%
data.sample()
# Out:
#      Consumer_ID   City  State  Age Gender Occupation Marital_Status Smoker  \
# 2141      C02142  Delhi  Delhi   23   Male    Student         Single     No
#
#      Drink_Level Budget_Level    Transport_Mode
# 2141         Non          Low  Public Transport

# %%
data.tail()
# Out:
#      Consumer_ID       City           State  Age  Gender Occupation  \
# 4995      C04996       Pune     Maharashtra   32    Male   Employed
# 4996      C04997    Kolkata     West Bengal   34  Female   Business
# 4997      C04998  Ahmedabad         Gujarat   24    Male    Student
# 4998      C04999     Jaipur       Rajasthan   35  Female   Employed
# 4999      C05000     Indore  Madhya Pradesh   37    Male   Business
#
#      Marital_Status Smoker Drink_Level Budget_Level    Transport_Mode
# 4995        Married     No      Casual       Medium              Bike
# 4996        Married    Yes      Social         High               Car
# 4997         Single     No         Non          Low  Public Transport
# 4998        Married     No      Casual       Medium              Bike
# 4999        Married    Yes      Social         High               Car

# %% [markdown]
# - There is no numeric_columns
# - There is only categorical_columns

# %% [markdown]
# <h2>Checking Unique Values

# %%
df2.nunique()
# Out:
# Consumer_ID          5000
# Preferred_Cuisine       8
# dtype: int64

# %%
df2["Preferred_Cuisine"].unique()
# Out:
# array(['Indian', 'Chinese', 'South Indian', 'North Indian', 'Street Food',
#        'Fast Food', 'Continental', 'Italian'], dtype=object)

# %% [markdown]
# <h2>Checking For Null Values

# %%
df2.isnull().sum()
# Out:
# Consumer_ID          0
# Preferred_Cuisine    0
# dtype: int64

# %% [markdown]
# <h4>There is no null values in table

# %% [markdown]
# <h3>Table 3 : Restaurant

# %%
df3.shape
# Out:
# (5000, 11)

# %%
df3.columns
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'City', 'State', 'Country',
#        'Price_Range', 'Pure_Veg', 'Alcohol_Served', 'Parking', 'Franchise',
#        'Online_Delivery'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Restaurant_ID    5000 non-null   object
#  1   Restaurant_Name  5000 non-null   object
#  2   City             5000 non-null   object
#  3   State            5000 non-null   object
#  4   Country          5000 non-null   object
#  5   Price_Range      5000 non-null   object
#  6   Pure_Veg         5000 non-null   object
#  7   Alcohol_Served   5000 non-null   object
#  8   Parking          4176 non-null   object
#  9   Franchise        5000 non-null   object
#  10  Online_Delivery  5000 non-null   object
# dtypes: object(11)
# memory usage: 429.8+ KB

# %%
df3.dtypes
# Out:
# Restaurant_ID      object
# Restaurant_Name    object
# City               object
# State              object
# Country            object
# Price_Range        object
# Pure_Veg           object
# Alcohol_Served     object
# Parking            object
# Franchise          object
# Online_Delivery    object
# dtype: object

# %%
df3.head()
# Out:
#   Restaurant_ID   Restaurant_Name        City        State Country  \
# 0        R00001     Delight Dhaba        Pune  Maharashtra   India
# 1        R00002      Delight Cafe  Chandigarh   Chandigarh   India
# 2        R00003     Plaza Kitchen       Delhi        Delhi   India
# 3        R00004  House Restaurant       Patna        Bihar   India
# 4        R00005   Heritage Palace   Bengaluru    Karnataka   India
#
#   Price_Range Pure_Veg Alcohol_Served  Parking Franchise Online_Delivery
# 0         Low       No       Full Bar   Public        No             Yes
# 1         Low       No             No   Public       Yes             Yes
# 2        High       No       Full Bar  Private        No              No
# 3      Medium       No    Beer & Wine  Private       Yes             Yes
# 4      Medium      Yes             No   Public        No             Yes

# %%
df3.sample()
# Out:
#      Restaurant_ID Restaurant_Name       City      State Country Price_Range  \
# 4597        R04598     Taste House  Hyderabad  Telangana   India      Medium
#
#      Pure_Veg Alcohol_Served Parking Franchise Online_Delivery
# 4597      Yes             No  Public        No             Yes

# %%
df3.tail()
# Out:
#      Restaurant_ID Restaurant_Name      City          State Country  \
# 4995        R04996   Garden Bistro     Delhi          Delhi   India
# 4996        R04997    Urban Palace  Amritsar         Punjab   India
# 4997        R04998    Royal Palace    Mumbai    Maharashtra   India
# 4998        R04999  Classic Corner     Patna          Bihar   India
# 4999        R05000     Green Dhaba     Noida  Uttar Pradesh   India
#
#      Price_Range Pure_Veg Alcohol_Served  Parking Franchise Online_Delivery
# 4995      Medium       No    Beer & Wine   Public       Yes             Yes
# 4996      Medium      Yes             No  Private       Yes             Yes
# 4997        High       No             No    Valet       Yes              No
# 4998      Medium       No             No   Public        No             Yes
# 4999      Medium      Yes             No   Public        No             Yes

# %% [markdown]
# <h2>Checking Unique Values

# %%
df3.nunique()
# Out:
# Restaurant_ID      5000
# Restaurant_Name     160
# City                 20
# State                14
# Country               1
# Price_Range           3
# Pure_Veg              2
# Alcohol_Served        3
# Parking               3
# Franchise             2
# Online_Delivery       2
# dtype: int64

# %%
df3["Restaurant_ID"].unique()
# Out:
# array(['R00001', 'R00002', 'R00003', ..., 'R04998', 'R04999', 'R05000'],
#       dtype=object)

# %%
df3["Restaurant_Name"].unique()
# Out:
# array(['Delight Dhaba', 'Delight Cafe', 'Plaza Kitchen',
#        'House Restaurant', 'Heritage Palace', 'Heritage Eatery',
#        'Flavors Cafe', 'Urban Eatery', 'Kitchen Kitchen',
#        'Flavors Eatery', 'Royal Restaurant', 'Taste House',
#        'Green Corner', 'Urban Dhaba', 'Urban Bistro', 'Flavors House',
#        'Garden Bistro', 'Heritage Dhaba', 'House Corner',
#        'Spice Restaurant', 'Urban Restaurant', 'Spice Bistro',
#        'Hub House', 'Kitchen Dhaba', 'Plaza Cafe', 'Heritage Kitchen',
#        'Flavors Dhaba', 'Royal Kitchen', 'House Dhaba', 'House Kitchen',
#        'Royal Cafe', 'Garden House', 'Taste Cafe', 'Delight Corner',
#        'Express Bistro', 'Express Dhaba', 'Royal Dhaba', 'Kitchen Palace',
#        'Garden Grill', 'Classic House', 'Kitchen Bistro', 'Green House',
#        'Tandoori Grill', 'Taste Grill', 'Express Cafe',
#        'Tandoori Kitchen', 'Green Grill', 'Green Cafe', 'Garden Eatery',
# ...

# %%
df3["City"].unique()
# Out:
# array(['Pune', 'Chandigarh', 'Delhi', 'Patna', 'Bengaluru', 'Ludhiana',
#        'Gurgaon', 'Lucknow', 'Jaipur', 'Bhopal', 'Kolkata', 'Faridabad',
#        'Chennai', 'Hyderabad', 'Noida', 'Mumbai', 'Kanpur', 'Amritsar',
#        'Ahmedabad', 'Indore'], dtype=object)

# %%
df3["State"].unique()
# Out:
# array(['Maharashtra', 'Chandigarh', 'Delhi', 'Bihar', 'Karnataka',
#        'Punjab', 'Haryana', 'Uttar Pradesh', 'Rajasthan',
#        'Madhya Pradesh', 'West Bengal', 'Tamil Nadu', 'Telangana',
#        'Gujarat'], dtype=object)

# %%
df3["Country"].unique()
# Out:
# array(['India'], dtype=object)

# %%
df3["Price_Range"].unique()
# Out:
# array(['Low', 'High', 'Medium'], dtype=object)

# %%
df3["Pure_Veg"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df3["Alcohol_Served"].unique()
# Out:
# array(['Full Bar', 'No', 'Beer & Wine'], dtype=object)

# %%
df3["Parking"].unique()
# Out:
# array(['Public', 'Private', 'Valet', nan], dtype=object)

# %%
df3["Franchise"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df3["Online_Delivery"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# <h2>Checking Null Values

# %%
df3.isnull().sum()
# Out:
# Restaurant_ID        0
# Restaurant_Name      0
# City                 0
# State                0
# Country              0
# Price_Range          0
# Pure_Veg             0
# Alcohol_Served       0
# Parking            824
# Franchise            0
# Online_Delivery      0
# dtype: int64

# %% [markdown]
# <h3>Table 4 : Rating

# %%
df4.shape
# Out:
# (5000, 6)

# %%
df4.columns
# Out:
# Index(['Consumer_ID', 'Restaurant_ID', 'Overall_Rating', 'Food_Rating',
#        'Service_Rating', 'Value_for_Money'],
#       dtype='object')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Consumer_ID      5000 non-null   object
#  1   Restaurant_ID    5000 non-null   object
#  2   Overall_Rating   5000 non-null   int64
#  3   Food_Rating      5000 non-null   int64
#  4   Service_Rating   5000 non-null   int64
#  5   Value_for_Money  5000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 234.5+ KB

# %%
df4.dtypes
# Out:
# Consumer_ID        object
# Restaurant_ID      object
# Overall_Rating      int64
# Food_Rating         int64
# Service_Rating      int64
# Value_for_Money     int64
# dtype: object

# %%
df4.describe()
# Out:
#        Overall_Rating  Food_Rating  Service_Rating  Value_for_Money
# count     5000.000000  5000.000000     5000.000000      5000.000000
# mean         3.486400     3.498400        3.467000         3.484600
# std          0.707612     1.105189        1.134182         1.128547
# min          2.000000     2.000000        2.000000         2.000000
# 25%          3.000000     3.000000        2.000000         2.000000
# 50%          3.000000     4.000000        3.000000         3.000000
# 75%          4.000000     4.000000        5.000000         5.000000
# max          5.000000     5.000000        5.000000         5.000000

# %%
df4.head()
# Out:
#   Consumer_ID Restaurant_ID  Overall_Rating  Food_Rating  Service_Rating  \
# 0      C00001        R03681               4            4               3
# 1      C00002        R00349               4            4               5
# 2      C00003        R02274               3            2               3
# 3      C00004        R00297               3            3               2
# 4      C00005        R04163               3            5               3
#
#    Value_for_Money
# 0                4
# 1                3
# 2                5
# 3                3
# 4                2

# %%
df4.sample()
# Out:
#     Consumer_ID Restaurant_ID  Overall_Rating  Food_Rating  Service_Rating  \
# 190      C00191        R01723               5            4               5
#
#      Value_for_Money
# 190                5

# %%
df4.tail()
# Out:
#      Consumer_ID Restaurant_ID  Overall_Rating  Food_Rating  Service_Rating  \
# 4995      C04996        R00791               3            2               5
# 4996      C04997        R04703               2            2               2
# 4997      C04998        R03950               4            4               5
# 4998      C04999        R03003               4            5               2
# 4999      C05000        R03957               4            4               2
#
#       Value_for_Money
# 4995                3
# 4996                3
# 4997                2
# 4998                4
# 4999                5

# %%
numeric_columns=df4.select_dtypes(["int64","float64"])
numeric_columns
# Out:
#       Overall_Rating  Food_Rating  Service_Rating  Value_for_Money
# 0                  4            4               3                4
# 1                  4            4               5                3
# 2                  3            2               3                5
# 3                  3            3               2                3
# 4                  3            5               3                2
# ...              ...          ...             ...              ...
# 4995               3            2               5                3
# 4996               2            2               2                3
# 4997               4            4               5                2
# 4998               4            5               2                4
# 4999               4            4               2                5
#
# [5000 rows x 4 columns]

# %%
numeric_columns.columns
# Out:
# Index(['Overall_Rating', 'Food_Rating', 'Service_Rating', 'Value_for_Money'], dtype='object')

# %%
Categorical_columns=df4.select_dtypes(["object"])
Categorical_columns
# Out:
#      Consumer_ID Restaurant_ID
# 0         C00001        R03681
# 1         C00002        R00349
# 2         C00003        R02274
# 3         C00004        R00297
# 4         C00005        R04163
# ...          ...           ...
# 4995      C04996        R00791
# 4996      C04997        R04703
# 4997      C04998        R03950
# 4998      C04999        R03003
# 4999      C05000        R03957
#
# [5000 rows x 2 columns]

# %%
Categorical_columns.columns
# Out:
# Index(['Consumer_ID', 'Restaurant_ID'], dtype='object')

# %% [markdown]
# <h2>Checking Unique Values

# %%
df4.nunique()
# Out:
# Consumer_ID        5000
# Restaurant_ID      3181
# Overall_Rating        4
# Food_Rating           4
# Service_Rating        4
# Value_for_Money       4
# dtype: int64

# %%
Categorical_columns["Restaurant_ID"].unique()
# Out:
# array(['R03681', 'R00349', 'R02274', ..., 'R03536', 'R03950', 'R03003'],
#       dtype=object)

# %%
Categorical_columns["Consumer_ID"].unique()
# Out:
# array(['C00001', 'C00002', 'C00003', ..., 'C04998', 'C04999', 'C05000'],
#       dtype=object)

# %% [markdown]
# <h2>Checking Null Values

# %%
df4.isnull().sum()
# Out:
# Consumer_ID        0
# Restaurant_ID      0
# Overall_Rating     0
# Food_Rating        0
# Service_Rating     0
# Value_for_Money    0
# dtype: int64

# %% [markdown]
# <h4>There is no null values in these table

# %% [markdown]
# <h3>Table 5 : Restaurant Cuisines

# %%
df5.shape
# Out:
# (5000, 2)

# %%
df5.columns
# Out:
# Index(['Restaurant_ID', 'Cuisine_Type'], dtype='object')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Restaurant_ID  5000 non-null   object
#  1   Cuisine_Type   5000 non-null   object
# dtypes: object(2)
# memory usage: 78.3+ KB

# %%
df5.dtypes
# Out:
# Restaurant_ID    object
# Cuisine_Type     object
# dtype: object

# %%
df5.head()
# Out:
#   Restaurant_ID Cuisine_Type
# 0        R00001       Bakery
# 1        R00002      Seafood
# 2        R00003     Gujarati
# 3        R00004      Bengali
# 4        R00005    Fast Food

# %%
df5.sample()
# Out:
#      Restaurant_ID Cuisine_Type
# 4622        R04623      Chinese

# %%
df5.tail()
# Out:
#      Restaurant_ID Cuisine_Type
# 4995        R04996       Kerala
# 4996        R04997    Chettinad
# 4997        R04998   Rajasthani
# 4998        R04999         Cafe
# 4999        R05000     Kashmiri

# %% [markdown]
# <h4>There Is no Numeric columns in this table

# %% [markdown]
# <h2>Checking Unique Values

# %%
df5.nunique()
# Out:
# Restaurant_ID    5000
# Cuisine_Type       25
# dtype: int64

# %%
df5["Restaurant_ID"].unique()
# Out:
# array(['R00001', 'R00002', 'R00003', ..., 'R04998', 'R04999', 'R05000'],
#       dtype=object)

# %%
df5["Cuisine_Type"].unique()
# Out:
# array(['Bakery', 'Seafood', 'Gujarati', 'Bengali', 'Fast Food', 'Mexican',
#        'Cafe', 'Rajasthani', 'Chinese', 'Kerala', 'BBQ', 'Punjabi',
#        'Goan', 'Mughlai', 'Maharashtrian', 'North Indian', 'South Indian',
#        'Street Food', 'Continental', 'Italian', 'Hyderabadi', 'Chettinad',
#        'Awadhi', 'Indo-Chinese', 'Kashmiri'], dtype=object)

# %% [markdown]
# <h2>Checking Null Values

# %%
df5.isnull().sum()
# Out:
# Restaurant_ID    0
# Cuisine_Type     0
# dtype: int64

# %% [markdown]
# <h4>There Is no null Values In dataset

# %% [markdown]
# <h2>Transfering dataset python to myql

# %%
pip install mysql-connector-python

# %%
import mysql.connector as connector
import pandas as pd

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("atharv@5104")
host = "localhost"
port = "3306"
database = "indian_restaurant"   # 🔥 must exist

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

engine.connect()
print("MySQL connected successfully")

df1.to_sql("customer", engine, if_exists="replace", index=False)
print("Table created successfully")
# Out:
# MySQL connected successfully
# Table created successfully

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("atharv@5104")
host = "localhost"
port = "3306"
database = "indian_restaurant"   # 🔥 must exist

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

engine.connect()
print("MySQL connected successfully")

df2.to_sql("customer_preference", engine, if_exists="replace", index=False)
print("Table created successfully")
# Out:
# MySQL connected successfully
# Table created successfully

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("atharv@5104")
host = "localhost"
port = "3306"
database = "indian_restaurant"   # 🔥 must exist

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

engine.connect()
print("MySQL connected successfully")

df3.to_sql("restaurant", engine, if_exists="replace", index=False)
print("Table created successfully")
# Out:
# MySQL connected successfully
# Table created successfully

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("atharv@5104")
host = "localhost"
port = "3306"
database = "indian_restaurant"   # 🔥 must exist

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

engine.connect()
print("MySQL connected successfully")

df4.to_sql("rating", engine, if_exists="replace", index=False)
print("Table created successfully")
# Out:
# MySQL connected successfully
# Table created successfully

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "root"
password = quote_plus("atharv@5104")
host = "localhost"
port = "3306"
database = "indian_restaurant"   # 🔥 must exist

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

engine.connect()
print("MySQL connected successfully")

df5.to_sql("restaurant_cuisines", engine, if_exists="replace", index=False)
print("Table created successfully")
# Out:
# MySQL connected successfully
# Table created successfully
